# %%
import pandas as pd
import numpy as np
import plotly
import importlib
import asana
import wartsila_asana_utils as wa

import prototype_wa_utilities as pwut

import plotly.express as px

# %%
importlib.reload(wa)
importlib.reload(pwut)
# Out:
# <module 'prototype_wa_utilities' from 'C:\\Users\\dha042\\Documents\\W_Development\\Resource_Planning\\prototype_wa_utilities.py'>

# %% [markdown]
# # 1 - Getting all the Data

# %%
df_global = wa.get_global_portfolio_data()

# %%
df_rstasks = wa.get_resource_project_data()

# %%
df_personnel = wa.get_delivery_personnel_data()

# %% [markdown]
# ## 1.1 - Merging Portfolio Data with Resource Task Data

# %%
df_rglobal = df_rstasks.merge(df_global, left_on='eso_project_name', right_on='name').drop(columns=['name'])

# %%
df_rglobal
# Out:
#                  assignee_name                   role     region  \
# 0                  Brian Pizzi      Solution Engineer  no_region
# 1                   unassigned                no_role  no_region
# 2                   unassigned                no_role  no_region
# 3                   unassigned                no_role  no_region
# 4                   unassigned                no_role  no_region
# ..                         ...                    ...        ...
# 460              Nabeel Yaseen      Solution Engineer       EUAF
# 461  alec.stablow@wartsila.com            SW Engineer       EUAF
# 462            Daniel Hockborn  Commissioning Manager       EUAF
# 463            Daniel Hockborn  Commissioning Manager       EUAF
# 464            Daniel Hockborn  Commissioning Manager       EUAF
#
#                  eso_project_name start_date   due_date project_type  \
# 0       P/22454 Clearway Rosamond 2023-06-05 2023-12-01      no_type
# 1       P/22454 Clearway Rosamond 2022-12-01 2022-12-02      no_type
# 2       P/22454 Clearway Rosamond 2022-12-29 2023-02-02      no_type
# 3       P/22454 Clearway Rosamond 2022-12-29 2023-02-02      no_type
# 4       P/22454 Clearway Rosamond        NaT 2022-12-01      no_type
# ..                            ...        ...        ...          ...
# 460  P/22201 SSE Salisbury 49.5MW 2022-04-01 2023-09-22          EPC
# 461  P/22201 SSE Salisbury 49.5MW 2022-04-01 2023-09-22          EPC
# 462  P/22201 SSE Salisbury 49.5MW        NaT 2022-08-31          EPC
# 463  P/22201 SSE Salisbury 49.5MW        NaT 2022-08-31          EPC
# 464  P/22201 SSE Salisbury 49.5MW        NaT 2022-08-31          EPC
#
#                   gid resource_type    [ESO] Stage  ... Power (MW) [ESO]  \
# 0    1202901532753744       project  G2 - Delivery  ...             none
# 1    1202901532753744       project  G2 - Delivery  ...             none
# 2    1202901532753744       project  G2 - Delivery  ...             none
# 3    1202901532753744       project  G2 - Delivery  ...             none
# 4    1202901532753744       project  G2 - Delivery  ...             none
# ..                ...           ...            ...  ...              ...
# 460  1202021927476446       project  G2 - Delivery  ...               50
# 461  1202021927476446       project  G2 - Delivery  ...               50
# 462  1202021927476446       project  G2 - Delivery  ...               50
# 463  1202021927476446       project  G2 - Delivery  ...               50
# 464  1202021927476446       project  G2 - Delivery  ...               50
#
#     Capacity (MWh) [ESO] Batt Enclosure (qty) Inverter Qty [ESO] ACC/DCC Qty  \
# 0                   none                 none               none        none
# 1                   none                 none               none        none
# 2                   none                 none               none        none
# 3                   none                 none               none        none
# 4                   none                 none               none        none
# ..                   ...                  ...                ...         ...
# 460                   99                   76                 17          26
# 461                   99                   76                 17          26
# 462                   99                   76                 17          26
# 463                   99                   76                 17          26
# 464                   99                   76                 17          26
#
#      Product Role [ESO] Delivery Roles [ESO] Status (Design) Effort level?
# 0       none       none                  NaN             NaN           NaN
# 1       none       none                  NaN             NaN           NaN
# 2       none       none                  NaN             NaN           NaN
# 3       none       none                  NaN             NaN           NaN
# 4       none       none                  NaN             NaN           NaN
# ..       ...        ...                  ...             ...           ...
# 460  Quantum  CPE Civil     Systems Engineer            none          none
# 461  Quantum  CPE Civil     Systems Engineer            none          none
# 462  Quantum  CPE Civil     Systems Engineer            none          none
# 463  Quantum  CPE Civil     Systems Engineer            none          none
# 464  Quantum  CPE Civil     Systems Engineer            none          none
#
# [465 rows x 25 columns]

# %% [markdown]
# # 2 - Data Engineering

# %%
def add_role_group_column(df):
#     df['role_group'] = df['Role [ESO]'] 
#     # Groups
#     cx_group = ['Commissioning Manager','Commissioning Engineer']
#     group_dict = {'Comm_Mgr-Engr':cx_group}
#     for k, v in group_dict.items():
    pass

# %%
def add_engineered_columns(df):
    df = pwut.add_workload_units(df)
    #df = add_role_group_column(df)
    return df

# %%
df = add_engineered_columns(df_rglobal)
df
# Out:
#                  assignee_name                   role     region  \
# 0                  Brian Pizzi      Solution Engineer  no_region
# 1                   unassigned                no_role  no_region
# 2                   unassigned                no_role  no_region
# 3                   unassigned                no_role  no_region
# 4                   unassigned                no_role  no_region
# ..                         ...                    ...        ...
# 460              Nabeel Yaseen      Solution Engineer       EUAF
# 461  alec.stablow@wartsila.com            SW Engineer       EUAF
# 462            Daniel Hockborn  Commissioning Manager       EUAF
# 463            Daniel Hockborn  Commissioning Manager       EUAF
# 464            Daniel Hockborn  Commissioning Manager       EUAF
#
#                  eso_project_name start_date   due_date project_type  \
# 0       P/22454 Clearway Rosamond 2023-06-05 2023-12-01      no_type
# 1       P/22454 Clearway Rosamond 2022-12-01 2022-12-02      no_type
# 2       P/22454 Clearway Rosamond 2022-12-29 2023-02-02      no_type
# 3       P/22454 Clearway Rosamond 2022-12-29 2023-02-02      no_type
# 4       P/22454 Clearway Rosamond        NaT 2022-12-01      no_type
# ..                            ...        ...        ...          ...
# 460  P/22201 SSE Salisbury 49.5MW 2022-04-01 2023-09-22          EPC
# 461  P/22201 SSE Salisbury 49.5MW 2022-04-01 2023-09-22          EPC
# 462  P/22201 SSE Salisbury 49.5MW        NaT 2022-08-31          EPC
# 463  P/22201 SSE Salisbury 49.5MW        NaT 2022-08-31          EPC
# 464  P/22201 SSE Salisbury 49.5MW        NaT 2022-08-31          EPC
#
#                   gid resource_type    [ESO] Stage  ... Capacity (MWh) [ESO]  \
# 0    1202901532753744       project  G2 - Delivery  ...                 none
# 1    1202901532753744       project  G2 - Delivery  ...                 none
# 2    1202901532753744       project  G2 - Delivery  ...                 none
# 3    1202901532753744       project  G2 - Delivery  ...                 none
# 4    1202901532753744       project  G2 - Delivery  ...                 none
# ..                ...           ...            ...  ...                  ...
# 460  1202021927476446       project  G2 - Delivery  ...                   99
# 461  1202021927476446       project  G2 - Delivery  ...                   99
# 462  1202021927476446       project  G2 - Delivery  ...                   99
# 463  1202021927476446       project  G2 - Delivery  ...                   99
# 464  1202021927476446       project  G2 - Delivery  ...                   99
#
#     Batt Enclosure (qty) Inverter Qty [ESO] ACC/DCC Qty  Product Role [ESO]  \
# 0                   none               none        none     none       none
# 1                   none               none        none     none       none
# 2                   none               none        none     none       none
# 3                   none               none        none     none       none
# 4                   none               none        none     none       none
# ..                   ...                ...         ...      ...        ...
# 460                   76                 17          26  Quantum  CPE Civil
# 461                   76                 17          26  Quantum  CPE Civil
# 462                   76                 17          26  Quantum  CPE Civil
# 463                   76                 17          26  Quantum  CPE Civil
# 464                   76                 17          26  Quantum  CPE Civil
#
#     Delivery Roles [ESO] Status (Design) Effort level? workload_units
# 0                    NaN             NaN           NaN              1
# 1                    NaN             NaN           NaN              1
# 2                    NaN             NaN           NaN              1
# 3                    NaN             NaN           NaN              1
# 4                    NaN             NaN           NaN              1
# ..                   ...             ...           ...            ...
# 460     Systems Engineer            none          none              1
# 461     Systems Engineer            none          none              1
# 462     Systems Engineer            none          none              1
# 463     Systems Engineer            none          none              1
# 464     Systems Engineer            none          none              1
#
# [465 rows x 26 columns]

# %% [markdown]
# # 3 - Preparing for Pipeline Analysis

# %% [markdown]
# ## 3.1 Development Breadcrumbs

# %%
# verifying length of auto-generated filter list
# combinations = len(pipeline_options) * len(region_options) * len(role_options)
# print(combinations)
# print('-'*5)
# len(filters_list_for_analysis)
# Out:
# 228
# -----
# 228

# %%
# filter_dict = {'region': 'AMER', 'role': 'System Engineer', '[ESO] Stage': 'G2 - Delivery'}

# %%
def make_list_of_all_filters(df):
    role_options = df['role'].unique().tolist()
    region_options = df['region'].unique().tolist()
    pipeline_options = df['[ESO] Stage'].unique().tolist()
    
    # make all filters
    filters_list_for_analysis = list()
    for region in region_options: 
        for role in role_options:
            for stage in pipeline_options:
                filters_list_for_analysis.append({'region': region, 'role': role, '[ESO] Stage': stage})
    
    return filters_list_for_analysis

# %%
make_list_of_all_filters(df)
# Out:
# [{'region': 'no_region',
#   'role': 'Solution Engineer',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'no_region', 'role': 'Solution Engineer', '[ESO] Stage': 'A'},
#  {'region': 'no_region',
#   'role': 'Solution Engineer',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'no_region', 'role': 'no_role', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'no_region', 'role': 'no_role', '[ESO] Stage': 'A'},
#  {'region': 'no_region', 'role': 'no_role', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'no_region',
#   'role': 'Commissioning Manager',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'no_region', 'role': 'Commissioning Manager', '[ESO] Stage': 'A'},
#  {'region': 'no_region',
#   'role': 'Commissioning Manager',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'no_region',
#   'role': 'System Engineer',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'no_region', 'role': 'System Engineer', '[ESO] Stage': 'A'},
#  {'region': 'no_region',
#   'role': 'System Engineer',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'no_region',
#   'role': 'Project Manager',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'no_region', 'role': 'Project Manager', '[ESO] Stage': 'A'},
#  {'region': 'no_region',
#   'role': 'Project Manager',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'no_region', 'role': 'CPE Civil', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'no_region', 'role': 'CPE Civil', '[ESO] Stage': 'A'},
#  {'region': 'no_region', 'role': 'CPE Civil', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'no_region',
#   'role': 'Commissioning Engineer',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'no_region', 'role': 'Commissioning Engineer', '[ESO] Stage': 'A'},
#  {'region': 'no_region',
#   'role': 'Commissioning Engineer',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'no_region',
#   'role': 'SW Engineer',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'no_region', 'role': 'SW Engineer', '[ESO] Stage': 'A'},
#  {'region': 'no_region',
#   'role': 'SW Engineer',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'no_region',
#   'role': 'Site Management',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'no_region', 'role': 'Site Management', '[ESO] Stage': 'A'},
#  {'region': 'no_region',
#   'role': 'Site Management',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'no_region',
#   'role': 'Electrical Site Supervisor',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'no_region',
#   'role': 'Electrical Site Supervisor',
#   '[ESO] Stage': 'A'},
#  {'region': 'no_region',
#   'role': 'Electrical Site Supervisor',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'no_region',
#   'role': 'Commissioning Technician',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'no_region',
#   'role': 'Commissioning Technician',
#   '[ESO] Stage': 'A'},
#  {'region': 'no_region',
#   'role': 'Commissioning Technician',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'no_region',
#   'role': 'CPE Electrical',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'no_region', 'role': 'CPE Electrical', '[ESO] Stage': 'A'},
#  {'region': 'no_region',
#   'role': 'CPE Electrical',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'no_region',
#   'role': 'Site Manager',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'no_region', 'role': 'Site Manager', '[ESO] Stage': 'A'},
#  {'region': 'no_region',
#   'role': 'Site Manager',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'no_region',
#   'role': 'Civil Engineer',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'no_region', 'role': 'Civil Engineer', '[ESO] Stage': 'A'},
#  {'region': 'no_region',
#   'role': 'Civil Engineer',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'no_region',
#   'role': 'Site Commissioning Manager',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'no_region',
#   'role': 'Site Commissioning Manager',
#   '[ESO] Stage': 'A'},
#  {'region': 'no_region',
#   'role': 'Site Commissioning Manager',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'no_region',
#   'role': 'Site HSE Manager',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'no_region', 'role': 'Site HSE Manager', '[ESO] Stage': 'A'},
#  {'region': 'no_region',
#   'role': 'Site HSE Manager',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'no_region',
#   'role': 'Civil Chief Project Engineer',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'no_region',
#   'role': 'Civil Chief Project Engineer',
#   '[ESO] Stage': 'A'},
#  {'region': 'no_region',
#   'role': 'Civil Chief Project Engineer',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'no_region',
#   'role': 'PE Electrical',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'no_region', 'role': 'PE Electrical', '[ESO] Stage': 'A'},
#  {'region': 'no_region',
#   'role': 'PE Electrical',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'no_region',
#   'role': 'Electrical Engineer - Delivery',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'no_region',
#   'role': 'Electrical Engineer - Delivery',
#   '[ESO] Stage': 'A'},
#  {'region': 'no_region',
#   'role': 'Electrical Engineer - Delivery',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'MEA',
#   'role': 'Solution Engineer',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'MEA', 'role': 'Solution Engineer', '[ESO] Stage': 'A'},
#  {'region': 'MEA',
#   'role': 'Solution Engineer',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'MEA', 'role': 'no_role', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'MEA', 'role': 'no_role', '[ESO] Stage': 'A'},
#  {'region': 'MEA', 'role': 'no_role', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'MEA',
#   'role': 'Commissioning Manager',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'MEA', 'role': 'Commissioning Manager', '[ESO] Stage': 'A'},
#  {'region': 'MEA',
#   'role': 'Commissioning Manager',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'MEA', 'role': 'System Engineer', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'MEA', 'role': 'System Engineer', '[ESO] Stage': 'A'},
#  {'region': 'MEA', 'role': 'System Engineer', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'MEA', 'role': 'Project Manager', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'MEA', 'role': 'Project Manager', '[ESO] Stage': 'A'},
#  {'region': 'MEA', 'role': 'Project Manager', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'MEA', 'role': 'CPE Civil', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'MEA', 'role': 'CPE Civil', '[ESO] Stage': 'A'},
#  {'region': 'MEA', 'role': 'CPE Civil', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'MEA',
#   'role': 'Commissioning Engineer',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'MEA', 'role': 'Commissioning Engineer', '[ESO] Stage': 'A'},
#  {'region': 'MEA',
#   'role': 'Commissioning Engineer',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'MEA', 'role': 'SW Engineer', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'MEA', 'role': 'SW Engineer', '[ESO] Stage': 'A'},
#  {'region': 'MEA', 'role': 'SW Engineer', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'MEA', 'role': 'Site Management', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'MEA', 'role': 'Site Management', '[ESO] Stage': 'A'},
#  {'region': 'MEA', 'role': 'Site Management', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'MEA',
#   'role': 'Electrical Site Supervisor',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'MEA', 'role': 'Electrical Site Supervisor', '[ESO] Stage': 'A'},
#  {'region': 'MEA',
#   'role': 'Electrical Site Supervisor',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'MEA',
#   'role': 'Commissioning Technician',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'MEA', 'role': 'Commissioning Technician', '[ESO] Stage': 'A'},
#  {'region': 'MEA',
#   'role': 'Commissioning Technician',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'MEA', 'role': 'CPE Electrical', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'MEA', 'role': 'CPE Electrical', '[ESO] Stage': 'A'},
#  {'region': 'MEA', 'role': 'CPE Electrical', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'MEA', 'role': 'Site Manager', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'MEA', 'role': 'Site Manager', '[ESO] Stage': 'A'},
#  {'region': 'MEA', 'role': 'Site Manager', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'MEA', 'role': 'Civil Engineer', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'MEA', 'role': 'Civil Engineer', '[ESO] Stage': 'A'},
#  {'region': 'MEA', 'role': 'Civil Engineer', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'MEA',
#   'role': 'Site Commissioning Manager',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'MEA', 'role': 'Site Commissioning Manager', '[ESO] Stage': 'A'},
#  {'region': 'MEA',
#   'role': 'Site Commissioning Manager',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'MEA', 'role': 'Site HSE Manager', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'MEA', 'role': 'Site HSE Manager', '[ESO] Stage': 'A'},
#  {'region': 'MEA',
#   'role': 'Site HSE Manager',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'MEA',
#   'role': 'Civil Chief Project Engineer',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'MEA', 'role': 'Civil Chief Project Engineer', '[ESO] Stage': 'A'},
#  {'region': 'MEA',
#   'role': 'Civil Chief Project Engineer',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'MEA', 'role': 'PE Electrical', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'MEA', 'role': 'PE Electrical', '[ESO] Stage': 'A'},
#  {'region': 'MEA', 'role': 'PE Electrical', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'MEA',
#   'role': 'Electrical Engineer - Delivery',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'MEA',
#   'role': 'Electrical Engineer - Delivery',
#   '[ESO] Stage': 'A'},
#  {'region': 'MEA',
#   'role': 'Electrical Engineer - Delivery',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'AMER',
#   'role': 'Solution Engineer',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'AMER', 'role': 'Solution Engineer', '[ESO] Stage': 'A'},
#  {'region': 'AMER',
#   'role': 'Solution Engineer',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'AMER', 'role': 'no_role', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'AMER', 'role': 'no_role', '[ESO] Stage': 'A'},
#  {'region': 'AMER', 'role': 'no_role', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'AMER',
#   'role': 'Commissioning Manager',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'AMER', 'role': 'Commissioning Manager', '[ESO] Stage': 'A'},
#  {'region': 'AMER',
#   'role': 'Commissioning Manager',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'AMER', 'role': 'System Engineer', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'AMER', 'role': 'System Engineer', '[ESO] Stage': 'A'},
#  {'region': 'AMER',
#   'role': 'System Engineer',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'AMER', 'role': 'Project Manager', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'AMER', 'role': 'Project Manager', '[ESO] Stage': 'A'},
#  {'region': 'AMER',
#   'role': 'Project Manager',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'AMER', 'role': 'CPE Civil', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'AMER', 'role': 'CPE Civil', '[ESO] Stage': 'A'},
#  {'region': 'AMER', 'role': 'CPE Civil', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'AMER',
#   'role': 'Commissioning Engineer',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'AMER', 'role': 'Commissioning Engineer', '[ESO] Stage': 'A'},
#  {'region': 'AMER',
#   'role': 'Commissioning Engineer',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'AMER', 'role': 'SW Engineer', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'AMER', 'role': 'SW Engineer', '[ESO] Stage': 'A'},
#  {'region': 'AMER', 'role': 'SW Engineer', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'AMER', 'role': 'Site Management', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'AMER', 'role': 'Site Management', '[ESO] Stage': 'A'},
#  {'region': 'AMER',
#   'role': 'Site Management',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'AMER',
#   'role': 'Electrical Site Supervisor',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'AMER', 'role': 'Electrical Site Supervisor', '[ESO] Stage': 'A'},
#  {'region': 'AMER',
#   'role': 'Electrical Site Supervisor',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'AMER',
#   'role': 'Commissioning Technician',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'AMER', 'role': 'Commissioning Technician', '[ESO] Stage': 'A'},
#  {'region': 'AMER',
#   'role': 'Commissioning Technician',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'AMER', 'role': 'CPE Electrical', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'AMER', 'role': 'CPE Electrical', '[ESO] Stage': 'A'},
#  {'region': 'AMER', 'role': 'CPE Electrical', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'AMER', 'role': 'Site Manager', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'AMER', 'role': 'Site Manager', '[ESO] Stage': 'A'},
#  {'region': 'AMER', 'role': 'Site Manager', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'AMER', 'role': 'Civil Engineer', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'AMER', 'role': 'Civil Engineer', '[ESO] Stage': 'A'},
#  {'region': 'AMER', 'role': 'Civil Engineer', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'AMER',
#   'role': 'Site Commissioning Manager',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'AMER', 'role': 'Site Commissioning Manager', '[ESO] Stage': 'A'},
#  {'region': 'AMER',
#   'role': 'Site Commissioning Manager',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'AMER',
#   'role': 'Site HSE Manager',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'AMER', 'role': 'Site HSE Manager', '[ESO] Stage': 'A'},
#  {'region': 'AMER',
#   'role': 'Site HSE Manager',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'AMER',
#   'role': 'Civil Chief Project Engineer',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'AMER',
#   'role': 'Civil Chief Project Engineer',
#   '[ESO] Stage': 'A'},
#  {'region': 'AMER',
#   'role': 'Civil Chief Project Engineer',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'AMER', 'role': 'PE Electrical', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'AMER', 'role': 'PE Electrical', '[ESO] Stage': 'A'},
#  {'region': 'AMER', 'role': 'PE Electrical', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'AMER',
#   'role': 'Electrical Engineer - Delivery',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'AMER',
#   'role': 'Electrical Engineer - Delivery',
#   '[ESO] Stage': 'A'},
#  {'region': 'AMER',
#   'role': 'Electrical Engineer - Delivery',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'EUAF',
#   'role': 'Solution Engineer',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'EUAF', 'role': 'Solution Engineer', '[ESO] Stage': 'A'},
#  {'region': 'EUAF',
#   'role': 'Solution Engineer',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'EUAF', 'role': 'no_role', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'EUAF', 'role': 'no_role', '[ESO] Stage': 'A'},
#  {'region': 'EUAF', 'role': 'no_role', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'EUAF',
#   'role': 'Commissioning Manager',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'EUAF', 'role': 'Commissioning Manager', '[ESO] Stage': 'A'},
#  {'region': 'EUAF',
#   'role': 'Commissioning Manager',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'EUAF', 'role': 'System Engineer', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'EUAF', 'role': 'System Engineer', '[ESO] Stage': 'A'},
#  {'region': 'EUAF',
#   'role': 'System Engineer',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'EUAF', 'role': 'Project Manager', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'EUAF', 'role': 'Project Manager', '[ESO] Stage': 'A'},
#  {'region': 'EUAF',
#   'role': 'Project Manager',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'EUAF', 'role': 'CPE Civil', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'EUAF', 'role': 'CPE Civil', '[ESO] Stage': 'A'},
#  {'region': 'EUAF', 'role': 'CPE Civil', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'EUAF',
#   'role': 'Commissioning Engineer',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'EUAF', 'role': 'Commissioning Engineer', '[ESO] Stage': 'A'},
#  {'region': 'EUAF',
#   'role': 'Commissioning Engineer',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'EUAF', 'role': 'SW Engineer', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'EUAF', 'role': 'SW Engineer', '[ESO] Stage': 'A'},
#  {'region': 'EUAF', 'role': 'SW Engineer', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'EUAF', 'role': 'Site Management', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'EUAF', 'role': 'Site Management', '[ESO] Stage': 'A'},
#  {'region': 'EUAF',
#   'role': 'Site Management',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'EUAF',
#   'role': 'Electrical Site Supervisor',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'EUAF', 'role': 'Electrical Site Supervisor', '[ESO] Stage': 'A'},
#  {'region': 'EUAF',
#   'role': 'Electrical Site Supervisor',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'EUAF',
#   'role': 'Commissioning Technician',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'EUAF', 'role': 'Commissioning Technician', '[ESO] Stage': 'A'},
#  {'region': 'EUAF',
#   'role': 'Commissioning Technician',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'EUAF', 'role': 'CPE Electrical', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'EUAF', 'role': 'CPE Electrical', '[ESO] Stage': 'A'},
#  {'region': 'EUAF', 'role': 'CPE Electrical', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'EUAF', 'role': 'Site Manager', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'EUAF', 'role': 'Site Manager', '[ESO] Stage': 'A'},
#  {'region': 'EUAF', 'role': 'Site Manager', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'EUAF', 'role': 'Civil Engineer', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'EUAF', 'role': 'Civil Engineer', '[ESO] Stage': 'A'},
#  {'region': 'EUAF', 'role': 'Civil Engineer', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'EUAF',
#   'role': 'Site Commissioning Manager',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'EUAF', 'role': 'Site Commissioning Manager', '[ESO] Stage': 'A'},
#  {'region': 'EUAF',
#   'role': 'Site Commissioning Manager',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'EUAF',
#   'role': 'Site HSE Manager',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'EUAF', 'role': 'Site HSE Manager', '[ESO] Stage': 'A'},
#  {'region': 'EUAF',
#   'role': 'Site HSE Manager',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'EUAF',
#   'role': 'Civil Chief Project Engineer',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'EUAF',
#   'role': 'Civil Chief Project Engineer',
#   '[ESO] Stage': 'A'},
#  {'region': 'EUAF',
#   'role': 'Civil Chief Project Engineer',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'EUAF', 'role': 'PE Electrical', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'EUAF', 'role': 'PE Electrical', '[ESO] Stage': 'A'},
#  {'region': 'EUAF', 'role': 'PE Electrical', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'EUAF',
#   'role': 'Electrical Engineer - Delivery',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'EUAF',
#   'role': 'Electrical Engineer - Delivery',
#   '[ESO] Stage': 'A'},
#  {'region': 'EUAF',
#   'role': 'Electrical Engineer - Delivery',
#   '[ESO] Stage': 'G3 - Lifecycle'}]

# %%
# df1 = pwut.apply_filter_from_dict(df, filters_list_for_analysis[99])
# df1
# Out:
# Empty DataFrame
# Columns: [assignee_name, role, region, eso_project_name, start_date, due_date, project_type, gid, resource_type, [ESO] Stage, Contract COD [ESO], City/State/Country [ESO], Priority, Project Type [ESO], Region [ESO], Power (MW) [ESO], Capacity (MWh) [ESO], Batt Enclosure (qty), Inverter Qty [ESO], ACC/DCC Qty, Product, Role [ESO], Delivery Roles [ESO], Status (Design), Effort level?, workload_units]
# Index: []
#
# [0 rows x 26 columns]

# %%
# verify all filters being applied
# for fil_d in filters_list_for_analysis:
#     print(fil_d)
#     df1 = pwut.apply_filter_from_dict(df, fil_d)
#     print(df1['role'].unique())
#     print(df1['region'].unique())
#     print(df1['[ESO] Stage'].unique())
#     print('-'*5)
# Out:
# {'region': 'no_region', 'role': 'Solution Engineer', '[ESO] Stage': 'G2 - Delivery'}
# ['Solution Engineer']
# ['no_region']
# ['G2 - Delivery']
# -----
# {'region': 'no_region', 'role': 'Solution Engineer', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'Solution Engineer', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'no_role', '[ESO] Stage': 'G2 - Delivery'}
# ['no_role']
# ['no_region']
# ['G2 - Delivery']
# -----
# {'region': 'no_region', 'role': 'no_role', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'no_role', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'Commissioning Manager', '[ESO] Stage': 'G2 - Delivery'}
# ['Commissioning Manager']
# ['no_region']
# ['G2 - Delivery']
# -----
# {'region': 'no_region', 'role': 'Commissioning Manager', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'Commissioning Manager', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'System Engineer', '[ESO] Stage': 'G2 - Delivery'}
# ['System Engineer']
# ['no_region']
# ['G2 - Delivery']
# -----
# {'region': 'no_region', 'role': 'System Engineer', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'System Engineer', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'Project Manager', '[ESO] Stage': 'G2 - Delivery'}
# ['Project Manager']
# ['no_region']
# ['G2 - Delivery']
# -----
# {'region': 'no_region', 'role': 'Project Manager', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'Project Manager', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'CPE Civil', '[ESO] Stage': 'G2 - Delivery'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'CPE Civil', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'CPE Civil', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'Commissioning Engineer', '[ESO] Stage': 'G2 - Delivery'}
# ['Commissioning Engineer']
# ['no_region']
# ['G2 - Delivery']
# -----
# {'region': 'no_region', 'role': 'Commissioning Engineer', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'Commissioning Engineer', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'SW Engineer', '[ESO] Stage': 'G2 - Delivery'}
# ['SW Engineer']
# ['no_region']
# ['G2 - Delivery']
# -----
# {'region': 'no_region', 'role': 'SW Engineer', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'SW Engineer', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'Site Management', '[ESO] Stage': 'G2 - Delivery'}
# ['Site Management']
# ['no_region']
# ['G2 - Delivery']
# -----
# {'region': 'no_region', 'role': 'Site Management', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'Site Management', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'Electrical Site Supervisor', '[ESO] Stage': 'G2 - Delivery'}
# ['Electrical Site Supervisor']
# ['no_region']
# ['G2 - Delivery']
# -----
# {'region': 'no_region', 'role': 'Electrical Site Supervisor', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'Electrical Site Supervisor', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'Commissioning Technician', '[ESO] Stage': 'G2 - Delivery'}
# ['Commissioning Technician']
# ['no_region']
# ['G2 - Delivery']
# -----
# {'region': 'no_region', 'role': 'Commissioning Technician', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'Commissioning Technician', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'CPE Electrical', '[ESO] Stage': 'G2 - Delivery'}
# ['CPE Electrical']
# ['no_region']
# ['G2 - Delivery']
# -----
# {'region': 'no_region', 'role': 'CPE Electrical', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'CPE Electrical', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'Site Manager', '[ESO] Stage': 'G2 - Delivery'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'Site Manager', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'Site Manager', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'Civil Engineer', '[ESO] Stage': 'G2 - Delivery'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'Civil Engineer', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'Civil Engineer', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'Site Commissioning Manager', '[ESO] Stage': 'G2 - Delivery'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'Site Commissioning Manager', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'Site Commissioning Manager', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'Site HSE Manager', '[ESO] Stage': 'G2 - Delivery'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'Site HSE Manager', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'Site HSE Manager', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'Civil Chief Project Engineer', '[ESO] Stage': 'G2 - Delivery'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'Civil Chief Project Engineer', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'Civil Chief Project Engineer', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'PE Electrical', '[ESO] Stage': 'G2 - Delivery'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'PE Electrical', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'PE Electrical', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'Electrical Engineer - Delivery', '[ESO] Stage': 'G2 - Delivery'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'Electrical Engineer - Delivery', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'no_region', 'role': 'Electrical Engineer - Delivery', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'MEA', 'role': 'Solution Engineer', '[ESO] Stage': 'G2 - Delivery'}
# ['Solution Engineer']
# ['MEA']
# ['G2 - Delivery']
# -----
# {'region': 'MEA', 'role': 'Solution Engineer', '[ESO] Stage': 'A'}
# ['Solution Engineer']
# ['MEA']
# ['A']
# -----
# {'region': 'MEA', 'role': 'Solution Engineer', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'MEA', 'role': 'no_role', '[ESO] Stage': 'G2 - Delivery'}
# ['no_role']
# ['MEA']
# ['G2 - Delivery']
# -----
# {'region': 'MEA', 'role': 'no_role', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'MEA', 'role': 'no_role', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'MEA', 'role': 'Commissioning Manager', '[ESO] Stage': 'G2 - Delivery'}
# ['Commissioning Manager']
# ['MEA']
# ['G2 - Delivery']
# -----
# {'region': 'MEA', 'role': 'Commissioning Manager', '[ESO] Stage': 'A'}
# ['Commissioning Manager']
# ['MEA']
# ['A']
# -----
# {'region': 'MEA', 'role': 'Commissioning Manager', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'MEA', 'role': 'System Engineer', '[ESO] Stage': 'G2 - Delivery'}
# ['System Engineer']
# ['MEA']
# ['G2 - Delivery']
# -----
# {'region': 'MEA', 'role': 'System Engineer', '[ESO] Stage': 'A'}
# ['System Engineer']
# ['MEA']
# ['A']
# -----
# {'region': 'MEA', 'role': 'System Engineer', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'MEA', 'role': 'Project Manager', '[ESO] Stage': 'G2 - Delivery'}
# ['Project Manager']
# ['MEA']
# ['G2 - Delivery']
# -----
# {'region': 'MEA', 'role': 'Project Manager', '[ESO] Stage': 'A'}
# ['Project Manager']
# ['MEA']
# ['A']
# -----
# {'region': 'MEA', 'role': 'Project Manager', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'MEA', 'role': 'CPE Civil', '[ESO] Stage': 'G2 - Delivery'}
# []
# []
# []
# -----
# {'region': 'MEA', 'role': 'CPE Civil', '[ESO] Stage': 'A'}
# ['CPE Civil']
# ['MEA']
# ['A']
# -----
# {'region': 'MEA', 'role': 'CPE Civil', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'MEA', 'role': 'Commissioning Engineer', '[ESO] Stage': 'G2 - Delivery'}
# []
# []
# []
# -----
# {'region': 'MEA', 'role': 'Commissioning Engineer', '[ESO] Stage': 'A'}
# ['Commissioning Engineer']
# ['MEA']
# ['A']
# -----
# {'region': 'MEA', 'role': 'Commissioning Engineer', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'MEA', 'role': 'SW Engineer', '[ESO] Stage': 'G2 - Delivery'}
# ['SW Engineer']
# ['MEA']
# ['G2 - Delivery']
# -----
# {'region': 'MEA', 'role': 'SW Engineer', '[ESO] Stage': 'A'}
# ['SW Engineer']
# ['MEA']
# ['A']
# -----
# {'region': 'MEA', 'role': 'SW Engineer', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'MEA', 'role': 'Site Management', '[ESO] Stage': 'G2 - Delivery'}
# ['Site Management']
# ['MEA']
# ['G2 - Delivery']
# -----
# {'region': 'MEA', 'role': 'Site Management', '[ESO] Stage': 'A'}
# ['Site Management']
# ['MEA']
# ['A']
# -----
# {'region': 'MEA', 'role': 'Site Management', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'MEA', 'role': 'Electrical Site Supervisor', '[ESO] Stage': 'G2 - Delivery'}
# ['Electrical Site Supervisor']
# ['MEA']
# ['G2 - Delivery']
# -----
# {'region': 'MEA', 'role': 'Electrical Site Supervisor', '[ESO] Stage': 'A'}
# ['Electrical Site Supervisor']
# ['MEA']
# ['A']
# -----
# {'region': 'MEA', 'role': 'Electrical Site Supervisor', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'MEA', 'role': 'Commissioning Technician', '[ESO] Stage': 'G2 - Delivery'}
# []
# []
# []
# -----
# {'region': 'MEA', 'role': 'Commissioning Technician', '[ESO] Stage': 'A'}
# ['Commissioning Technician']
# ['MEA']
# ['A']
# -----
# {'region': 'MEA', 'role': 'Commissioning Technician', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'MEA', 'role': 'CPE Electrical', '[ESO] Stage': 'G2 - Delivery'}
# ['CPE Electrical']
# ['MEA']
# ['G2 - Delivery']
# -----
# {'region': 'MEA', 'role': 'CPE Electrical', '[ESO] Stage': 'A'}
# ['CPE Electrical']
# ['MEA']
# ['A']
# -----
# {'region': 'MEA', 'role': 'CPE Electrical', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'MEA', 'role': 'Site Manager', '[ESO] Stage': 'G2 - Delivery'}
# []
# []
# []
# -----
# {'region': 'MEA', 'role': 'Site Manager', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'MEA', 'role': 'Site Manager', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'MEA', 'role': 'Civil Engineer', '[ESO] Stage': 'G2 - Delivery'}
# []
# []
# []
# -----
# {'region': 'MEA', 'role': 'Civil Engineer', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'MEA', 'role': 'Civil Engineer', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'MEA', 'role': 'Site Commissioning Manager', '[ESO] Stage': 'G2 - Delivery'}
# []
# []
# []
# -----
# {'region': 'MEA', 'role': 'Site Commissioning Manager', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'MEA', 'role': 'Site Commissioning Manager', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'MEA', 'role': 'Site HSE Manager', '[ESO] Stage': 'G2 - Delivery'}
# []
# []
# []
# -----
# {'region': 'MEA', 'role': 'Site HSE Manager', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'MEA', 'role': 'Site HSE Manager', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'MEA', 'role': 'Civil Chief Project Engineer', '[ESO] Stage': 'G2 - Delivery'}
# []
# []
# []
# -----
# {'region': 'MEA', 'role': 'Civil Chief Project Engineer', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'MEA', 'role': 'Civil Chief Project Engineer', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'MEA', 'role': 'PE Electrical', '[ESO] Stage': 'G2 - Delivery'}
# ['PE Electrical']
# ['MEA']
# ['G2 - Delivery']
# -----
# {'region': 'MEA', 'role': 'PE Electrical', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'MEA', 'role': 'PE Electrical', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'MEA', 'role': 'Electrical Engineer - Delivery', '[ESO] Stage': 'G2 - Delivery'}
# ['Electrical Engineer - Delivery']
# ['MEA']
# ['G2 - Delivery']
# -----
# {'region': 'MEA', 'role': 'Electrical Engineer - Delivery', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'MEA', 'role': 'Electrical Engineer - Delivery', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'AMER', 'role': 'Solution Engineer', '[ESO] Stage': 'G2 - Delivery'}
# ['Solution Engineer']
# ['AMER']
# ['G2 - Delivery']
# -----
# {'region': 'AMER', 'role': 'Solution Engineer', '[ESO] Stage': 'A'}
# ['Solution Engineer']
# ['AMER']
# ['A']
# -----
# {'region': 'AMER', 'role': 'Solution Engineer', '[ESO] Stage': 'G3 - Lifecycle'}
# ['Solution Engineer']
# ['AMER']
# ['G3 - Lifecycle']
# -----
# {'region': 'AMER', 'role': 'no_role', '[ESO] Stage': 'G2 - Delivery'}
# ['no_role']
# ['AMER']
# ['G2 - Delivery']
# -----
# {'region': 'AMER', 'role': 'no_role', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'AMER', 'role': 'no_role', '[ESO] Stage': 'G3 - Lifecycle'}
# ['no_role']
# ['AMER']
# ['G3 - Lifecycle']
# -----
# {'region': 'AMER', 'role': 'Commissioning Manager', '[ESO] Stage': 'G2 - Delivery'}
# ['Commissioning Manager']
# ['AMER']
# ['G2 - Delivery']
# -----
# {'region': 'AMER', 'role': 'Commissioning Manager', '[ESO] Stage': 'A'}
# ['Commissioning Manager']
# ['AMER']
# ['A']
# -----
# {'region': 'AMER', 'role': 'Commissioning Manager', '[ESO] Stage': 'G3 - Lifecycle'}
# ['Commissioning Manager']
# ['AMER']
# ['G3 - Lifecycle']
# -----
# {'region': 'AMER', 'role': 'System Engineer', '[ESO] Stage': 'G2 - Delivery'}
# ['System Engineer']
# ['AMER']
# ['G2 - Delivery']
# -----
# {'region': 'AMER', 'role': 'System Engineer', '[ESO] Stage': 'A'}
# ['System Engineer']
# ['AMER']
# ['A']
# -----
# {'region': 'AMER', 'role': 'System Engineer', '[ESO] Stage': 'G3 - Lifecycle'}
# ['System Engineer']
# ['AMER']
# ['G3 - Lifecycle']
# -----
# {'region': 'AMER', 'role': 'Project Manager', '[ESO] Stage': 'G2 - Delivery'}
# ['Project Manager']
# ['AMER']
# ['G2 - Delivery']
# -----
# {'region': 'AMER', 'role': 'Project Manager', '[ESO] Stage': 'A'}
# ['Project Manager']
# ['AMER']
# ['A']
# -----
# {'region': 'AMER', 'role': 'Project Manager', '[ESO] Stage': 'G3 - Lifecycle'}
# ['Project Manager']
# ['AMER']
# ['G3 - Lifecycle']
# -----
# {'region': 'AMER', 'role': 'CPE Civil', '[ESO] Stage': 'G2 - Delivery'}
# []
# []
# []
# -----
# {'region': 'AMER', 'role': 'CPE Civil', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'AMER', 'role': 'CPE Civil', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'AMER', 'role': 'Commissioning Engineer', '[ESO] Stage': 'G2 - Delivery'}
# ['Commissioning Engineer']
# ['AMER']
# ['G2 - Delivery']
# -----
# {'region': 'AMER', 'role': 'Commissioning Engineer', '[ESO] Stage': 'A'}
# ['Commissioning Engineer']
# ['AMER']
# ['A']
# -----
# {'region': 'AMER', 'role': 'Commissioning Engineer', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'AMER', 'role': 'SW Engineer', '[ESO] Stage': 'G2 - Delivery'}
# ['SW Engineer']
# ['AMER']
# ['G2 - Delivery']
# -----
# {'region': 'AMER', 'role': 'SW Engineer', '[ESO] Stage': 'A'}
# ['SW Engineer']
# ['AMER']
# ['A']
# -----
# {'region': 'AMER', 'role': 'SW Engineer', '[ESO] Stage': 'G3 - Lifecycle'}
# ['SW Engineer']
# ['AMER']
# ['G3 - Lifecycle']
# -----
# {'region': 'AMER', 'role': 'Site Management', '[ESO] Stage': 'G2 - Delivery'}
# ['Site Management']
# ['AMER']
# ['G2 - Delivery']
# -----
# {'region': 'AMER', 'role': 'Site Management', '[ESO] Stage': 'A'}
# ['Site Management']
# ['AMER']
# ['A']
# -----
# {'region': 'AMER', 'role': 'Site Management', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'AMER', 'role': 'Electrical Site Supervisor', '[ESO] Stage': 'G2 - Delivery'}
# ['Electrical Site Supervisor']
# ['AMER']
# ['G2 - Delivery']
# -----
# {'region': 'AMER', 'role': 'Electrical Site Supervisor', '[ESO] Stage': 'A'}
# ['Electrical Site Supervisor']
# ['AMER']
# ['A']
# -----
# {'region': 'AMER', 'role': 'Electrical Site Supervisor', '[ESO] Stage': 'G3 - Lifecycle'}
# ['Electrical Site Supervisor']
# ['AMER']
# ['G3 - Lifecycle']
# -----
# {'region': 'AMER', 'role': 'Commissioning Technician', '[ESO] Stage': 'G2 - Delivery'}
# ['Commissioning Technician']
# ['AMER']
# ['G2 - Delivery']
# -----
# {'region': 'AMER', 'role': 'Commissioning Technician', '[ESO] Stage': 'A'}
# ['Commissioning Technician']
# ['AMER']
# ['A']
# -----
# {'region': 'AMER', 'role': 'Commissioning Technician', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'AMER', 'role': 'CPE Electrical', '[ESO] Stage': 'G2 - Delivery'}
# ['CPE Electrical']
# ['AMER']
# ['G2 - Delivery']
# -----
# {'region': 'AMER', 'role': 'CPE Electrical', '[ESO] Stage': 'A'}
# ['CPE Electrical']
# ['AMER']
# ['A']
# -----
# {'region': 'AMER', 'role': 'CPE Electrical', '[ESO] Stage': 'G3 - Lifecycle'}
# ['CPE Electrical']
# ['AMER']
# ['G3 - Lifecycle']
# -----
# {'region': 'AMER', 'role': 'Site Manager', '[ESO] Stage': 'G2 - Delivery'}
# ['Site Manager']
# ['AMER']
# ['G2 - Delivery']
# -----
# {'region': 'AMER', 'role': 'Site Manager', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'AMER', 'role': 'Site Manager', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'AMER', 'role': 'Civil Engineer', '[ESO] Stage': 'G2 - Delivery'}
# ['Civil Engineer']
# ['AMER']
# ['G2 - Delivery']
# -----
# {'region': 'AMER', 'role': 'Civil Engineer', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'AMER', 'role': 'Civil Engineer', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'AMER', 'role': 'Site Commissioning Manager', '[ESO] Stage': 'G2 - Delivery'}
# []
# []
# []
# -----
# {'region': 'AMER', 'role': 'Site Commissioning Manager', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'AMER', 'role': 'Site Commissioning Manager', '[ESO] Stage': 'G3 - Lifecycle'}
# ['Site Commissioning Manager']
# ['AMER']
# ['G3 - Lifecycle']
# -----
# {'region': 'AMER', 'role': 'Site HSE Manager', '[ESO] Stage': 'G2 - Delivery'}
# []
# []
# []
# -----
# {'region': 'AMER', 'role': 'Site HSE Manager', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'AMER', 'role': 'Site HSE Manager', '[ESO] Stage': 'G3 - Lifecycle'}
# ['Site HSE Manager']
# ['AMER']
# ['G3 - Lifecycle']
# -----
# {'region': 'AMER', 'role': 'Civil Chief Project Engineer', '[ESO] Stage': 'G2 - Delivery'}
# ['Civil Chief Project Engineer']
# ['AMER']
# ['G2 - Delivery']
# -----
# {'region': 'AMER', 'role': 'Civil Chief Project Engineer', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'AMER', 'role': 'Civil Chief Project Engineer', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'AMER', 'role': 'PE Electrical', '[ESO] Stage': 'G2 - Delivery'}
# []
# []
# []
# -----
# {'region': 'AMER', 'role': 'PE Electrical', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'AMER', 'role': 'PE Electrical', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'AMER', 'role': 'Electrical Engineer - Delivery', '[ESO] Stage': 'G2 - Delivery'}
# []
# []
# []
# -----
# {'region': 'AMER', 'role': 'Electrical Engineer - Delivery', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'AMER', 'role': 'Electrical Engineer - Delivery', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'EUAF', 'role': 'Solution Engineer', '[ESO] Stage': 'G2 - Delivery'}
# ['Solution Engineer']
# ['EUAF']
# ['G2 - Delivery']
# -----
# {'region': 'EUAF', 'role': 'Solution Engineer', '[ESO] Stage': 'A'}
# ['Solution Engineer']
# ['EUAF']
# ['A']
# -----
# {'region': 'EUAF', 'role': 'Solution Engineer', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'EUAF', 'role': 'no_role', '[ESO] Stage': 'G2 - Delivery'}
# ['no_role']
# ['EUAF']
# ['G2 - Delivery']
# -----
# {'region': 'EUAF', 'role': 'no_role', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'EUAF', 'role': 'no_role', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'EUAF', 'role': 'Commissioning Manager', '[ESO] Stage': 'G2 - Delivery'}
# ['Commissioning Manager']
# ['EUAF']
# ['G2 - Delivery']
# -----
# {'region': 'EUAF', 'role': 'Commissioning Manager', '[ESO] Stage': 'A'}
# ['Commissioning Manager']
# ['EUAF']
# ['A']
# -----
# {'region': 'EUAF', 'role': 'Commissioning Manager', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'EUAF', 'role': 'System Engineer', '[ESO] Stage': 'G2 - Delivery'}
# ['System Engineer']
# ['EUAF']
# ['G2 - Delivery']
# -----
# {'region': 'EUAF', 'role': 'System Engineer', '[ESO] Stage': 'A'}
# ['System Engineer']
# ['EUAF']
# ['A']
# -----
# {'region': 'EUAF', 'role': 'System Engineer', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'EUAF', 'role': 'Project Manager', '[ESO] Stage': 'G2 - Delivery'}
# ['Project Manager']
# ['EUAF']
# ['G2 - Delivery']
# -----
# {'region': 'EUAF', 'role': 'Project Manager', '[ESO] Stage': 'A'}
# ['Project Manager']
# ['EUAF']
# ['A']
# -----
# {'region': 'EUAF', 'role': 'Project Manager', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'EUAF', 'role': 'CPE Civil', '[ESO] Stage': 'G2 - Delivery'}
# []
# []
# []
# -----
# {'region': 'EUAF', 'role': 'CPE Civil', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'EUAF', 'role': 'CPE Civil', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'EUAF', 'role': 'Commissioning Engineer', '[ESO] Stage': 'G2 - Delivery'}
# ['Commissioning Engineer']
# ['EUAF']
# ['G2 - Delivery']
# -----
# {'region': 'EUAF', 'role': 'Commissioning Engineer', '[ESO] Stage': 'A'}
# ['Commissioning Engineer']
# ['EUAF']
# ['A']
# -----
# {'region': 'EUAF', 'role': 'Commissioning Engineer', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'EUAF', 'role': 'SW Engineer', '[ESO] Stage': 'G2 - Delivery'}
# ['SW Engineer']
# ['EUAF']
# ['G2 - Delivery']
# -----
# {'region': 'EUAF', 'role': 'SW Engineer', '[ESO] Stage': 'A'}
# ['SW Engineer']
# ['EUAF']
# ['A']
# -----
# {'region': 'EUAF', 'role': 'SW Engineer', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'EUAF', 'role': 'Site Management', '[ESO] Stage': 'G2 - Delivery'}
# ['Site Management']
# ['EUAF']
# ['G2 - Delivery']
# -----
# {'region': 'EUAF', 'role': 'Site Management', '[ESO] Stage': 'A'}
# ['Site Management']
# ['EUAF']
# ['A']
# -----
# {'region': 'EUAF', 'role': 'Site Management', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'EUAF', 'role': 'Electrical Site Supervisor', '[ESO] Stage': 'G2 - Delivery'}
# ['Electrical Site Supervisor']
# ['EUAF']
# ['G2 - Delivery']
# -----
# {'region': 'EUAF', 'role': 'Electrical Site Supervisor', '[ESO] Stage': 'A'}
# ['Electrical Site Supervisor']
# ['EUAF']
# ['A']
# -----
# {'region': 'EUAF', 'role': 'Electrical Site Supervisor', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'EUAF', 'role': 'Commissioning Technician', '[ESO] Stage': 'G2 - Delivery'}
# ['Commissioning Technician']
# ['EUAF']
# ['G2 - Delivery']
# -----
# {'region': 'EUAF', 'role': 'Commissioning Technician', '[ESO] Stage': 'A'}
# ['Commissioning Technician']
# ['EUAF']
# ['A']
# -----
# {'region': 'EUAF', 'role': 'Commissioning Technician', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'EUAF', 'role': 'CPE Electrical', '[ESO] Stage': 'G2 - Delivery'}
# ['CPE Electrical']
# ['EUAF']
# ['G2 - Delivery']
# -----
# {'region': 'EUAF', 'role': 'CPE Electrical', '[ESO] Stage': 'A'}
# ['CPE Electrical']
# ['EUAF']
# ['A']
# -----
# {'region': 'EUAF', 'role': 'CPE Electrical', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'EUAF', 'role': 'Site Manager', '[ESO] Stage': 'G2 - Delivery'}
# []
# []
# []
# -----
# {'region': 'EUAF', 'role': 'Site Manager', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'EUAF', 'role': 'Site Manager', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'EUAF', 'role': 'Civil Engineer', '[ESO] Stage': 'G2 - Delivery'}
# ['Civil Engineer']
# ['EUAF']
# ['G2 - Delivery']
# -----
# {'region': 'EUAF', 'role': 'Civil Engineer', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'EUAF', 'role': 'Civil Engineer', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'EUAF', 'role': 'Site Commissioning Manager', '[ESO] Stage': 'G2 - Delivery'}
# []
# []
# []
# -----
# {'region': 'EUAF', 'role': 'Site Commissioning Manager', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'EUAF', 'role': 'Site Commissioning Manager', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'EUAF', 'role': 'Site HSE Manager', '[ESO] Stage': 'G2 - Delivery'}
# []
# []
# []
# -----
# {'region': 'EUAF', 'role': 'Site HSE Manager', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'EUAF', 'role': 'Site HSE Manager', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'EUAF', 'role': 'Civil Chief Project Engineer', '[ESO] Stage': 'G2 - Delivery'}
# []
# []
# []
# -----
# {'region': 'EUAF', 'role': 'Civil Chief Project Engineer', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'EUAF', 'role': 'Civil Chief Project Engineer', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'EUAF', 'role': 'PE Electrical', '[ESO] Stage': 'G2 - Delivery'}
# []
# []
# []
# -----
# {'region': 'EUAF', 'role': 'PE Electrical', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'EUAF', 'role': 'PE Electrical', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----
# {'region': 'EUAF', 'role': 'Electrical Engineer - Delivery', '[ESO] Stage': 'G2 - Delivery'}
# ['Electrical Engineer - Delivery']
# ['EUAF']
# ['G2 - Delivery']
# -----
# {'region': 'EUAF', 'role': 'Electrical Engineer - Delivery', '[ESO] Stage': 'A'}
# []
# []
# []
# -----
# {'region': 'EUAF', 'role': 'Electrical Engineer - Delivery', '[ESO] Stage': 'G3 - Lifecycle'}
# []
# []
# []
# -----

# %% [markdown]
# ## 3.2 Final Function

# %%
filters_list = pwut.make_list_of_workload_pre_analysis_filters(df)
# apply the analysis function to each dict in the above list
# Out:
# [{'region': 'no_region',
#   'role': 'Solution Engineer',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'no_region', 'role': 'Solution Engineer', '[ESO] Stage': 'A'},
#  {'region': 'no_region',
#   'role': 'Solution Engineer',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'no_region', 'role': 'no_role', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'no_region', 'role': 'no_role', '[ESO] Stage': 'A'},
#  {'region': 'no_region', 'role': 'no_role', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'no_region',
#   'role': 'Commissioning Manager',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'no_region', 'role': 'Commissioning Manager', '[ESO] Stage': 'A'},
#  {'region': 'no_region',
#   'role': 'Commissioning Manager',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'no_region',
#   'role': 'System Engineer',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'no_region', 'role': 'System Engineer', '[ESO] Stage': 'A'},
#  {'region': 'no_region',
#   'role': 'System Engineer',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'no_region',
#   'role': 'Project Manager',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'no_region', 'role': 'Project Manager', '[ESO] Stage': 'A'},
#  {'region': 'no_region',
#   'role': 'Project Manager',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'no_region', 'role': 'CPE Civil', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'no_region', 'role': 'CPE Civil', '[ESO] Stage': 'A'},
#  {'region': 'no_region', 'role': 'CPE Civil', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'no_region',
#   'role': 'Commissioning Engineer',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'no_region', 'role': 'Commissioning Engineer', '[ESO] Stage': 'A'},
#  {'region': 'no_region',
#   'role': 'Commissioning Engineer',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'no_region',
#   'role': 'SW Engineer',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'no_region', 'role': 'SW Engineer', '[ESO] Stage': 'A'},
#  {'region': 'no_region',
#   'role': 'SW Engineer',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'no_region',
#   'role': 'Site Management',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'no_region', 'role': 'Site Management', '[ESO] Stage': 'A'},
#  {'region': 'no_region',
#   'role': 'Site Management',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'no_region',
#   'role': 'Electrical Site Supervisor',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'no_region',
#   'role': 'Electrical Site Supervisor',
#   '[ESO] Stage': 'A'},
#  {'region': 'no_region',
#   'role': 'Electrical Site Supervisor',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'no_region',
#   'role': 'Commissioning Technician',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'no_region',
#   'role': 'Commissioning Technician',
#   '[ESO] Stage': 'A'},
#  {'region': 'no_region',
#   'role': 'Commissioning Technician',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'no_region',
#   'role': 'CPE Electrical',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'no_region', 'role': 'CPE Electrical', '[ESO] Stage': 'A'},
#  {'region': 'no_region',
#   'role': 'CPE Electrical',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'no_region',
#   'role': 'Site Manager',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'no_region', 'role': 'Site Manager', '[ESO] Stage': 'A'},
#  {'region': 'no_region',
#   'role': 'Site Manager',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'no_region',
#   'role': 'Civil Engineer',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'no_region', 'role': 'Civil Engineer', '[ESO] Stage': 'A'},
#  {'region': 'no_region',
#   'role': 'Civil Engineer',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'no_region',
#   'role': 'Site Commissioning Manager',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'no_region',
#   'role': 'Site Commissioning Manager',
#   '[ESO] Stage': 'A'},
#  {'region': 'no_region',
#   'role': 'Site Commissioning Manager',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'no_region',
#   'role': 'Site HSE Manager',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'no_region', 'role': 'Site HSE Manager', '[ESO] Stage': 'A'},
#  {'region': 'no_region',
#   'role': 'Site HSE Manager',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'no_region',
#   'role': 'Civil Chief Project Engineer',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'no_region',
#   'role': 'Civil Chief Project Engineer',
#   '[ESO] Stage': 'A'},
#  {'region': 'no_region',
#   'role': 'Civil Chief Project Engineer',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'no_region',
#   'role': 'PE Electrical',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'no_region', 'role': 'PE Electrical', '[ESO] Stage': 'A'},
#  {'region': 'no_region',
#   'role': 'PE Electrical',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'no_region',
#   'role': 'Electrical Engineer - Delivery',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'no_region',
#   'role': 'Electrical Engineer - Delivery',
#   '[ESO] Stage': 'A'},
#  {'region': 'no_region',
#   'role': 'Electrical Engineer - Delivery',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'MEA',
#   'role': 'Solution Engineer',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'MEA', 'role': 'Solution Engineer', '[ESO] Stage': 'A'},
#  {'region': 'MEA',
#   'role': 'Solution Engineer',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'MEA', 'role': 'no_role', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'MEA', 'role': 'no_role', '[ESO] Stage': 'A'},
#  {'region': 'MEA', 'role': 'no_role', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'MEA',
#   'role': 'Commissioning Manager',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'MEA', 'role': 'Commissioning Manager', '[ESO] Stage': 'A'},
#  {'region': 'MEA',
#   'role': 'Commissioning Manager',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'MEA', 'role': 'System Engineer', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'MEA', 'role': 'System Engineer', '[ESO] Stage': 'A'},
#  {'region': 'MEA', 'role': 'System Engineer', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'MEA', 'role': 'Project Manager', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'MEA', 'role': 'Project Manager', '[ESO] Stage': 'A'},
#  {'region': 'MEA', 'role': 'Project Manager', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'MEA', 'role': 'CPE Civil', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'MEA', 'role': 'CPE Civil', '[ESO] Stage': 'A'},
#  {'region': 'MEA', 'role': 'CPE Civil', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'MEA',
#   'role': 'Commissioning Engineer',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'MEA', 'role': 'Commissioning Engineer', '[ESO] Stage': 'A'},
#  {'region': 'MEA',
#   'role': 'Commissioning Engineer',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'MEA', 'role': 'SW Engineer', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'MEA', 'role': 'SW Engineer', '[ESO] Stage': 'A'},
#  {'region': 'MEA', 'role': 'SW Engineer', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'MEA', 'role': 'Site Management', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'MEA', 'role': 'Site Management', '[ESO] Stage': 'A'},
#  {'region': 'MEA', 'role': 'Site Management', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'MEA',
#   'role': 'Electrical Site Supervisor',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'MEA', 'role': 'Electrical Site Supervisor', '[ESO] Stage': 'A'},
#  {'region': 'MEA',
#   'role': 'Electrical Site Supervisor',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'MEA',
#   'role': 'Commissioning Technician',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'MEA', 'role': 'Commissioning Technician', '[ESO] Stage': 'A'},
#  {'region': 'MEA',
#   'role': 'Commissioning Technician',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'MEA', 'role': 'CPE Electrical', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'MEA', 'role': 'CPE Electrical', '[ESO] Stage': 'A'},
#  {'region': 'MEA', 'role': 'CPE Electrical', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'MEA', 'role': 'Site Manager', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'MEA', 'role': 'Site Manager', '[ESO] Stage': 'A'},
#  {'region': 'MEA', 'role': 'Site Manager', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'MEA', 'role': 'Civil Engineer', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'MEA', 'role': 'Civil Engineer', '[ESO] Stage': 'A'},
#  {'region': 'MEA', 'role': 'Civil Engineer', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'MEA',
#   'role': 'Site Commissioning Manager',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'MEA', 'role': 'Site Commissioning Manager', '[ESO] Stage': 'A'},
#  {'region': 'MEA',
#   'role': 'Site Commissioning Manager',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'MEA', 'role': 'Site HSE Manager', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'MEA', 'role': 'Site HSE Manager', '[ESO] Stage': 'A'},
#  {'region': 'MEA',
#   'role': 'Site HSE Manager',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'MEA',
#   'role': 'Civil Chief Project Engineer',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'MEA', 'role': 'Civil Chief Project Engineer', '[ESO] Stage': 'A'},
#  {'region': 'MEA',
#   'role': 'Civil Chief Project Engineer',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'MEA', 'role': 'PE Electrical', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'MEA', 'role': 'PE Electrical', '[ESO] Stage': 'A'},
#  {'region': 'MEA', 'role': 'PE Electrical', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'MEA',
#   'role': 'Electrical Engineer - Delivery',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'MEA',
#   'role': 'Electrical Engineer - Delivery',
#   '[ESO] Stage': 'A'},
#  {'region': 'MEA',
#   'role': 'Electrical Engineer - Delivery',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'AMER',
#   'role': 'Solution Engineer',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'AMER', 'role': 'Solution Engineer', '[ESO] Stage': 'A'},
#  {'region': 'AMER',
#   'role': 'Solution Engineer',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'AMER', 'role': 'no_role', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'AMER', 'role': 'no_role', '[ESO] Stage': 'A'},
#  {'region': 'AMER', 'role': 'no_role', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'AMER',
#   'role': 'Commissioning Manager',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'AMER', 'role': 'Commissioning Manager', '[ESO] Stage': 'A'},
#  {'region': 'AMER',
#   'role': 'Commissioning Manager',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'AMER', 'role': 'System Engineer', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'AMER', 'role': 'System Engineer', '[ESO] Stage': 'A'},
#  {'region': 'AMER',
#   'role': 'System Engineer',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'AMER', 'role': 'Project Manager', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'AMER', 'role': 'Project Manager', '[ESO] Stage': 'A'},
#  {'region': 'AMER',
#   'role': 'Project Manager',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'AMER', 'role': 'CPE Civil', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'AMER', 'role': 'CPE Civil', '[ESO] Stage': 'A'},
#  {'region': 'AMER', 'role': 'CPE Civil', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'AMER',
#   'role': 'Commissioning Engineer',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'AMER', 'role': 'Commissioning Engineer', '[ESO] Stage': 'A'},
#  {'region': 'AMER',
#   'role': 'Commissioning Engineer',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'AMER', 'role': 'SW Engineer', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'AMER', 'role': 'SW Engineer', '[ESO] Stage': 'A'},
#  {'region': 'AMER', 'role': 'SW Engineer', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'AMER', 'role': 'Site Management', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'AMER', 'role': 'Site Management', '[ESO] Stage': 'A'},
#  {'region': 'AMER',
#   'role': 'Site Management',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'AMER',
#   'role': 'Electrical Site Supervisor',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'AMER', 'role': 'Electrical Site Supervisor', '[ESO] Stage': 'A'},
#  {'region': 'AMER',
#   'role': 'Electrical Site Supervisor',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'AMER',
#   'role': 'Commissioning Technician',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'AMER', 'role': 'Commissioning Technician', '[ESO] Stage': 'A'},
#  {'region': 'AMER',
#   'role': 'Commissioning Technician',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'AMER', 'role': 'CPE Electrical', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'AMER', 'role': 'CPE Electrical', '[ESO] Stage': 'A'},
#  {'region': 'AMER', 'role': 'CPE Electrical', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'AMER', 'role': 'Site Manager', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'AMER', 'role': 'Site Manager', '[ESO] Stage': 'A'},
#  {'region': 'AMER', 'role': 'Site Manager', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'AMER', 'role': 'Civil Engineer', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'AMER', 'role': 'Civil Engineer', '[ESO] Stage': 'A'},
#  {'region': 'AMER', 'role': 'Civil Engineer', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'AMER',
#   'role': 'Site Commissioning Manager',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'AMER', 'role': 'Site Commissioning Manager', '[ESO] Stage': 'A'},
#  {'region': 'AMER',
#   'role': 'Site Commissioning Manager',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'AMER',
#   'role': 'Site HSE Manager',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'AMER', 'role': 'Site HSE Manager', '[ESO] Stage': 'A'},
#  {'region': 'AMER',
#   'role': 'Site HSE Manager',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'AMER',
#   'role': 'Civil Chief Project Engineer',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'AMER',
#   'role': 'Civil Chief Project Engineer',
#   '[ESO] Stage': 'A'},
#  {'region': 'AMER',
#   'role': 'Civil Chief Project Engineer',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'AMER', 'role': 'PE Electrical', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'AMER', 'role': 'PE Electrical', '[ESO] Stage': 'A'},
#  {'region': 'AMER', 'role': 'PE Electrical', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'AMER',
#   'role': 'Electrical Engineer - Delivery',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'AMER',
#   'role': 'Electrical Engineer - Delivery',
#   '[ESO] Stage': 'A'},
#  {'region': 'AMER',
#   'role': 'Electrical Engineer - Delivery',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'EUAF',
#   'role': 'Solution Engineer',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'EUAF', 'role': 'Solution Engineer', '[ESO] Stage': 'A'},
#  {'region': 'EUAF',
#   'role': 'Solution Engineer',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'EUAF', 'role': 'no_role', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'EUAF', 'role': 'no_role', '[ESO] Stage': 'A'},
#  {'region': 'EUAF', 'role': 'no_role', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'EUAF',
#   'role': 'Commissioning Manager',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'EUAF', 'role': 'Commissioning Manager', '[ESO] Stage': 'A'},
#  {'region': 'EUAF',
#   'role': 'Commissioning Manager',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'EUAF', 'role': 'System Engineer', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'EUAF', 'role': 'System Engineer', '[ESO] Stage': 'A'},
#  {'region': 'EUAF',
#   'role': 'System Engineer',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'EUAF', 'role': 'Project Manager', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'EUAF', 'role': 'Project Manager', '[ESO] Stage': 'A'},
#  {'region': 'EUAF',
#   'role': 'Project Manager',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'EUAF', 'role': 'CPE Civil', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'EUAF', 'role': 'CPE Civil', '[ESO] Stage': 'A'},
#  {'region': 'EUAF', 'role': 'CPE Civil', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'EUAF',
#   'role': 'Commissioning Engineer',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'EUAF', 'role': 'Commissioning Engineer', '[ESO] Stage': 'A'},
#  {'region': 'EUAF',
#   'role': 'Commissioning Engineer',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'EUAF', 'role': 'SW Engineer', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'EUAF', 'role': 'SW Engineer', '[ESO] Stage': 'A'},
#  {'region': 'EUAF', 'role': 'SW Engineer', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'EUAF', 'role': 'Site Management', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'EUAF', 'role': 'Site Management', '[ESO] Stage': 'A'},
#  {'region': 'EUAF',
#   'role': 'Site Management',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'EUAF',
#   'role': 'Electrical Site Supervisor',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'EUAF', 'role': 'Electrical Site Supervisor', '[ESO] Stage': 'A'},
#  {'region': 'EUAF',
#   'role': 'Electrical Site Supervisor',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'EUAF',
#   'role': 'Commissioning Technician',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'EUAF', 'role': 'Commissioning Technician', '[ESO] Stage': 'A'},
#  {'region': 'EUAF',
#   'role': 'Commissioning Technician',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'EUAF', 'role': 'CPE Electrical', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'EUAF', 'role': 'CPE Electrical', '[ESO] Stage': 'A'},
#  {'region': 'EUAF', 'role': 'CPE Electrical', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'EUAF', 'role': 'Site Manager', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'EUAF', 'role': 'Site Manager', '[ESO] Stage': 'A'},
#  {'region': 'EUAF', 'role': 'Site Manager', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'EUAF', 'role': 'Civil Engineer', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'EUAF', 'role': 'Civil Engineer', '[ESO] Stage': 'A'},
#  {'region': 'EUAF', 'role': 'Civil Engineer', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'EUAF',
#   'role': 'Site Commissioning Manager',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'EUAF', 'role': 'Site Commissioning Manager', '[ESO] Stage': 'A'},
#  {'region': 'EUAF',
#   'role': 'Site Commissioning Manager',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'EUAF',
#   'role': 'Site HSE Manager',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'EUAF', 'role': 'Site HSE Manager', '[ESO] Stage': 'A'},
#  {'region': 'EUAF',
#   'role': 'Site HSE Manager',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'EUAF',
#   'role': 'Civil Chief Project Engineer',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'EUAF',
#   'role': 'Civil Chief Project Engineer',
#   '[ESO] Stage': 'A'},
#  {'region': 'EUAF',
#   'role': 'Civil Chief Project Engineer',
#   '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'EUAF', 'role': 'PE Electrical', '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'EUAF', 'role': 'PE Electrical', '[ESO] Stage': 'A'},
#  {'region': 'EUAF', 'role': 'PE Electrical', '[ESO] Stage': 'G3 - Lifecycle'},
#  {'region': 'EUAF',
#   'role': 'Electrical Engineer - Delivery',
#   '[ESO] Stage': 'G2 - Delivery'},
#  {'region': 'EUAF',
#   'role': 'Electrical Engineer - Delivery',
#   '[ESO] Stage': 'A'},
#  {'region': 'EUAF',
#   'role': 'Electrical Engineer - Delivery',
#   '[ESO] Stage': 'G3 - Lifecycle'}]

# %% [markdown]
# # 4 Outline for Final Steps

# %% [markdown]
# 1. create collecting list for the dfs returned by analysis function
# 2. apply analysis function for filtered df for each filter in 'filters_list'
# 3. append returned df to collector from step 1
# 4. generate final dataframe with all analysis results

# %% [markdown]
# # Refactoring the resource Analysis

# %%
### Initial Data PreProcessing 
def prepare_data_for_analysis(df_in, use_pj_groups=True)
    """
    Input
    -----
    df_in : dataframe - preformatted tasks from asan api
    use_pj_groups : apply groupings to colocated Wartsila Projects
    
    Returns
    -------
    
    
    """

    if use_pj_groups:
        df_tasks = make_project_groups(df_in.copy())
        print('using groups')
    else:
        df_tasks = df_in.copy()
   
    ## Unassigned - Cx
    # get all cx 'unassigned' tasks (denoted by 'Antti Pitkanen' as assignee)
    df_t = df_tasks
    df_t = df_t[df_t['assignee_name']=='Antti Pitkänen']

    ## Reference Cx Personnel
    pdb_list = wa.get_persondb_api_data()
    df_personnel_master = wa.make_persondb_df(pdb_list)
    df_p_all = df_personnel_master.copy()

    cx_all_persons = df_p_all[df_p_all['role'].isin(['Commissioning Manager', 'Commissioning Engineer'])].sort_values('region')
    cx_all_persons_count = cx_all_persons['person_name'].nunique()
    list_all_cx_persons = cx_all_persons['person_name'].tolist()

    ## Assigned - Cx
    # Get tasks assigned to Cx Managers or Cx Engineers
    roles_list = ['Commissioning Manager', 'Commissioning Engineer']
    df_ass = df_tasks.copy()
    df_ass = df_ass[df_ass['role'].isin(roles_list)]

    # exclude unassigned tasks
    df_ass = df_tasks.copy()
    exclude_assignee_list = ['Antti Pitkänen', 'unassigned']
    df_ass = df_ass[~df_ass['assignee_name'].isin(exclude_assignee_list)]

    # verify assignees against master list
    # todo determine if we need to add region filter
    df_ass = df_ass[df_ass['assignee_name'].isin(cx_all_persons['person_name'].to_list())]

    ## Assigned and Unassigned 
    df_cx_all = pd.concat([df_t, df_ass])
    
    return df_cx_all, df_t, df_ass

# %%
### Applying Analysis Functions 
    ## return values

### Create Plots
